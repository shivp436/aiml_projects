# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/the-stranger-web/jovian_Data_Analyst/refs/heads/main/italy-covid-daywise.csv"

# %%
from urllib.request import urlretrieve

# %%
urlretrieve(url)
# Out:
# ('/tmp/tmpritl53ij', <http.client.HTTPMessage at 0x78c36fb33a60>)

# %%
import os

# %%
covid_df = pd.read_csv(url)

# %%
covid_df.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
# a dataframe is more like a dictionary of lists
  # rather than a list of dictionaries

df = {
    'date' : ['2020-08-30', '2020-09-01', '', None],
    'new_cases' : [1444, 1365, 0, 0],
    'new_deaths' : [1, 4, 6, 8],
    'new_test' : [24342, 3343, 23432, 333]
}

# it is not a list of dictionaries

# %%
total_cases = covid_df.new_cases.sum()
total_deaths = covid_df.new_deaths.sum()

# %%
print('The number of total reported cases is {} and the number of reported deaths is {}.'.format(
    total_cases
    , total_deaths
))
# Out:
# The number of total reported cases is 271515.0 and the number of reported deaths is 35497.0.

# %%
death_rate = total_deaths * 100 / total_cases
print(death_rate)
# Out:
# 13.073679170579894

# %%
covid_df.head()
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  2019-12-31        0.0         0.0        NaN
# 1  2020-01-01        0.0         0.0        NaN
# 2  2020-01-02        0.0         0.0        NaN
# 3  2020-01-03        0.0         0.0        NaN
# 4  2020-01-04        0.0         0.0        NaN

# %%
covid_df['date'] = pd.to_datetime(covid_df['date'])

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    datetime64[ns]
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 7.9 KB

# %%
covid_df.describe()
# Out:
#                       date    new_cases  new_deaths     new_tests
# count                  248   248.000000  248.000000    135.000000
# mean   2020-05-02 12:00:00  1094.818548  143.133065  31699.674074
# min    2019-12-31 00:00:00  -148.000000  -31.000000   7841.000000
# 25%    2020-03-01 18:00:00   123.000000    3.000000  25259.000000
# 50%    2020-05-02 12:00:00   342.000000   17.000000  29545.000000
# 75%    2020-07-03 06:00:00  1371.750000  175.250000  37711.000000
# max    2020-09-03 00:00:00  6557.000000  971.000000  95273.000000
# std                    NaN  1554.508002  227.105538  11622.209757

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday

# %%
monthly_grouped = covid_df.groupby(['year', 'month'])

# %%
monthly_df = monthly_grouped[['new_cases', 'new_deaths', 'new_tests']].sum()

# %%
monthly_df
# Out:
#             new_cases  new_deaths  new_tests
# year month
# 2019 12           0.0         0.0        0.0
# 2020 1            3.0         0.0        0.0
#      2          885.0        21.0        0.0
#      3       100851.0     11570.0        0.0
#      4       101852.0     16091.0   419591.0
#      5        29073.0      5658.0  1078720.0
#      6         7772.0      1404.0   830354.0
#      7         6722.0       388.0   797692.0
#      8        21060.0       345.0  1098704.0
#      9         3297.0        20.0    54395.0
